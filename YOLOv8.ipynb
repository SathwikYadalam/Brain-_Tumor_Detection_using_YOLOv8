# %%
# !pip install ultralytics==8.0.20
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.2/261.2 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 kB 22.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 48.7 MB/s eta 0:00:00
# ...

# %%
from PIL import Image
import PIL.Image
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.2/78.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
 from google.colab import drive
 drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/IoT-Data
# Out:
# /content/drive/MyDrive/IoT-Data

# %%
# %cd /content/drive/MyDrive/IoT-Data
# !yolo task=detect mode=train model=yolov8s.pt data=IoT-Data.yaml epochs=200 imgsz=512 plots=True
# Out:
# ^C

# %%
# !ls runs/detect/train2/
# Out:
# args.yaml					    train_batch2070.jpg
# confusion_matrix.png				    train_batch2071.jpg
# events.out.tfevents.1679979255.c6d73a95ca43.2731.0  train_batch2072.jpg
# F1_curve.png					    train_batch2.jpg
# P_curve.png					    val_batch0_labels.jpg
# PR_curve.png					    val_batch0_pred.jpg
# R_curve.png					    val_batch1_labels.jpg
# results.csv					    val_batch1_pred.jpg
# results.png					    val_batch2_labels.jpg
# train_batch0.jpg				    val_batch2_pred.jpg
# train_batch1.jpg				    weights

# %%
Image(filename='runs/detect/train2/confusion_matrix.png',width=600)

# %%
Image(filename='runs/detect/train2/results.png',width=600)

# %%
 # !yolo task=detect mode=val model=runs/detect/train2/weights/best.pt data=IoT-Data.yaml
# Out:
# 2023-04-15 04:24:53.706137: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-15 04:24:54.923483: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/IoT-Data/val/labels.cache... 112 images, 14 backgrounds, 0 corrupt: 100% 126/126 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:05<00:00,  1.47it/s]
#                    all        126        123       0.52      0.705      0.599      0.464
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt source="/content/drive/MyDrive/IoT-Data/training/images/00095_226.jpg" save=True
# Out:
# /bin/bash: yolo: command not found

# %%
fp = open("/content/drive/MyDrive/IoT-Data/runs/detect/predict15/00095_226.jpg","rb")
img = PIL.Image.open(fp)
img.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7F59AD3E0B80>

# %%
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt source="/content/drive/MyDrive/IoT-Data/training/images/Cancer (542).jpg" save=True
# Out:
# 2023-04-15 04:25:50.358012: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-15 04:25:51.233137: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# image 1/1 /content/drive/MyDrive/IoT-Data/training/images/Cancer (542).jpg: 512x512 1 Tumor, 11.2ms
# Speed: 0.7ms pre-process, 11.2ms inference, 98.4ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs/detect/predict16

# %%
fp = open("/content/drive/MyDrive/IoT-Data/runs/detect/predict16/Cancer (542).jpg","rb")
img = PIL.Image.open(fp)
img.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7F58D55F0880>

# %%
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt source="/content/drive/MyDrive/IoT-Data/training/images/Cancer (561).jpg" save=True
# Out:
# 2023-04-15 04:29:37.299847: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-15 04:29:38.136769: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# image 1/1 /content/drive/MyDrive/IoT-Data/training/images/Cancer (561).jpg: 512x512 1 Tumor, 11.2ms
# Speed: 0.6ms pre-process, 11.2ms inference, 95.2ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs/detect/predict19

# %%
fp = open("/content/drive/MyDrive/IoT-Data/runs/detect/predict18/Cancer (561).jpg","rb")
img = PIL.Image.open(fp)
img.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7F58D3CE4EE0>
